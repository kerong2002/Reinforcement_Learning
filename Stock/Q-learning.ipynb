# %%
import numpy as np
import pandas as pd
#import tensorflow as tf
import tensorflow.compat.v1 as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.python.framework import ops
##sns.set()

# %%
df = pd.read_csv('./dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random
tf.compat.v1.disable_eager_execution()

class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3884\1819718061.py:26: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
# C:\Users\User\AppData\Local\Temp\ipykernel_3884\1819718061.py:27: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.layers.dense(feed, self.action_size)
# epoch: 10, total rewards: 112.205319.3, cost: 0.957716, total money: 10112.205319
# epoch: 20, total rewards: 257.185238.3, cost: 0.311062, total money: 10257.185238
# epoch: 30, total rewards: 284.115354.3, cost: 0.188648, total money: 10284.115354
# epoch: 40, total rewards: 270.525327.3, cost: 0.144951, total money: 10270.525327
# epoch: 50, total rewards: 315.095275.3, cost: 0.120252, total money: 10315.095275
# epoch: 60, total rewards: 329.685363.3, cost: 0.106739, total money: 10329.685363
# epoch: 70, total rewards: 351.405333.3, cost: 0.095744, total money: 10351.405333
# epoch: 80, total rewards: 202.595337.3, cost: 0.088827, total money: 10202.595337
# epoch: 90, total rewards: 210.065248.3, cost: 0.079999, total money: 10210.065248
# epoch: 100, total rewards: 320.965211.3, cost: 0.073705, total money: 10320.965211
# epoch: 110, total rewards: 219.425234.3, cost: 0.782459, total money: 10219.425234
# epoch: 120, total rewards: 148.015201.3, cost: 0.060630, total money: 10148.015201
# epoch: 130, total rewards: 158.565310.3, cost: 0.191257, total money: 10158.565310
# epoch: 140, total rewards: 23.235354.3, cost: 0.079654, total money: 10023.235354
# epoch: 150, total rewards: 190.565249.3, cost: 0.114996, total money: 10190.565249
# epoch: 160, total rewards: 259.235233.3, cost: 0.046783, total money: 10259.235233
# epoch: 170, total rewards: 198.065249.3, cost: 0.042791, total money: 10198.065249
# epoch: 180, total rewards: 270.415285.3, cost: 0.051799, total money: 10270.415285
# epoch: 190, total rewards: 260.835146.3, cost: 0.039920, total money: 10260.835146
# epoch: 200, total rewards: 315.625247.3, cost: 0.036210, total money: 10315.625247

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 2: buy 1 unit at price 762.020020, total balance 9237.979980
# day 3, sell 1 unit at price 782.520020, investment 2.690218 %, total balance 10020.500000,
# day 6: buy 1 unit at price 762.559998, total balance 9257.940002
# day 7: buy 1 unit at price 754.020020, total balance 8503.919982
# day 10, sell 1 unit at price 764.479980, investment 0.251781 %, total balance 9268.399962,
# day 12, sell 1 unit at price 760.539978, investment 0.864693 %, total balance 10028.939940,
# day 15: buy 1 unit at price 760.989990, total balance 9267.949950
# day 16, sell 1 unit at price 761.679993, investment 0.090672 %, total balance 10029.629943,
# day 26: buy 1 unit at price 789.289978, total balance 9240.339965
# day 29, sell 1 unit at price 797.070007, investment 0.985700 %, total balance 10037.409972,
# day 35: buy 1 unit at price 791.260010, total balance 9246.149962
# day 37: buy 1 unit at price 791.549988, total balance 8454.599974
# day 38, sell 1 unit at price 785.049988, investment -0.784827 %, total balance 9239.649962,
# day 39: buy 1 unit at price 782.789978, total balance 8456.859984
# day 40, sell 1 unit at price 771.820007, investment -2.492575 %, total balance 9228.679991,
# day 43, sell 1 unit at price 794.020020, investment 1.434617 %, total balance 10022.700011,
# day 45: buy 1 unit at price 806.650024, total balance 9216.049987
# day 48, sell 1 unit at price 806.359985, investment -0.035956 %, total balance 10022.409972,
# day 49: buy 1 unit at price 807.880005, total balance 9214.529967
# day 50: buy 1 unit at price 804.609985, total balance 8409.919982
# day 51, sell 1 unit at price 806.070007, investment -0.224043 %, total balance 9215.989989,
# day 52: buy 1 unit at price 802.174988, total balance 8413.815001
# day 54, sell 1 unit at price 819.309998, investment 1.826974 %, total balance 9233.124999,
# day 55, sell 1 unit at price 823.869995, investment 2.704523 %, total balance 10056.994994,
# day 57: buy 1 unit at price 832.150024, total balance 9224.844970
# day 58: buy 1 unit at price 823.309998, total balance 8401.534972
# day 60: buy 1 unit at price 796.789978, total balance 7604.744994
# day 62, sell 1 unit at price 798.530029, investment -4.040136 %, total balance 8403.275023,
# day 63, sell 1 unit at price 801.489990, investment -2.650279 %, total balance 9204.765013,
# day 64, sell 1 unit at price 801.340027, investment 0.571047 %, total balance 10006.105040,
# day 65: buy 1 unit at price 806.969971, total balance 9199.135069
# day 67, sell 1 unit at price 809.559998, investment 0.320957 %, total balance 10008.695067,
# day 69: buy 1 unit at price 819.239990, total balance 9189.455077
# day 70, sell 1 unit at price 820.450012, investment 0.147701 %, total balance 10009.905089,
# day 82: buy 1 unit at price 829.080017, total balance 9180.825072
# day 83, sell 1 unit at price 827.780029, investment -0.156799 %, total balance 10008.605101,
# day 84: buy 1 unit at price 831.909973, total balance 9176.695128
# day 87, sell 1 unit at price 843.250000, investment 1.363132 %, total balance 10019.945128,
# day 89: buy 1 unit at price 845.619995, total balance 9174.325133
# day 90, sell 1 unit at price 847.200012, investment 0.186847 %, total balance 10021.525145,
# day 93: buy 1 unit at price 848.400024, total balance 9173.125121
# day 94, sell 1 unit at price 830.460022, investment -2.114569 %, total balance 10003.585143,
# day 95: buy 1 unit at price 829.590027, total balance 9173.995116
# day 96, sell 1 unit at price 817.580017, investment -1.447704 %, total balance 9991.575133,
# day 102: buy 1 unit at price 829.559998, total balance 9162.015135
# day 104: buy 1 unit at price 834.570007, total balance 8327.445128
# day 106, sell 1 unit at price 827.880005, investment -0.202516 %, total balance 9155.325133,
# day 107: buy 1 unit at price 824.669983, total balance 8330.655150
# day 108: buy 1 unit at price 824.729980, total balance 7505.925170
# day 111, sell 1 unit at price 823.559998, investment -1.319243 %, total balance 8329.485168,
# day 112: buy 1 unit at price 837.169983, total balance 7492.315185
# day 113, sell 1 unit at price 836.820007, investment 1.473320 %, total balance 8329.135192,
# day 114, sell 1 unit at price 838.210022, investment 1.634479 %, total balance 9167.345214,
# day 116: buy 1 unit at price 843.190002, total balance 8324.155212
# day 118, sell 1 unit at price 872.299988, investment 4.196281 %, total balance 9196.455200,
# day 119: buy 1 unit at price 871.729980, total balance 8324.725220
# day 120, sell 1 unit at price 874.250000, investment 3.683630 %, total balance 9198.975220,
# day 122, sell 1 unit at price 912.570007, investment 4.684940 %, total balance 10111.545227,
# day 133: buy 1 unit at price 943.000000, total balance 9168.545227
# day 134: buy 1 unit at price 919.619995, total balance 8248.925232
# day 136: buy 1 unit at price 934.010010, total balance 7314.915222
# day 137: buy 1 unit at price 941.859985, total balance 6373.055237
# day 138, sell 1 unit at price 948.820007, investment 0.617180 %, total balance 7321.875244,
# day 139, sell 1 unit at price 954.960022, investment 3.842895 %, total balance 8276.835266,
# day 140, sell 1 unit at price 969.539978, investment 3.804024 %, total balance 9246.375244,
# day 142, sell 1 unit at price 975.880005, investment 3.612004 %, total balance 10222.255249,
# day 143: buy 1 unit at price 964.859985, total balance 9257.395264
# day 145: buy 1 unit at price 975.599976, total balance 8281.795288
# day 147, sell 1 unit at price 976.570007, investment 1.213650 %, total balance 9258.365295,
# day 148: buy 1 unit at price 980.940002, total balance 8277.425293
# day 149, sell 1 unit at price 983.409973, investment 0.800533 %, total balance 9260.835266,
# day 151: buy 1 unit at price 942.900024, total balance 8317.935242
# day 152: buy 1 unit at price 953.400024, total balance 7364.535218
# day 153, sell 1 unit at price 950.760010, investment -3.076640 %, total balance 8315.295228,
# day 154, sell 1 unit at price 942.309998, investment -0.062576 %, total balance 9257.605226,
# day 155, sell 1 unit at price 939.780029, investment -1.428571 %, total balance 10197.385255,
# day 161: buy 1 unit at price 952.270020, total balance 9245.115235
# day 163, sell 1 unit at price 940.489990, investment -1.237047 %, total balance 10185.605225,
# day 166: buy 1 unit at price 898.700012, total balance 9286.905213
# day 167: buy 1 unit at price 911.710022, total balance 8375.195191
# day 170, sell 1 unit at price 928.799988, investment 3.349280 %, total balance 9303.995179,
# day 174, sell 1 unit at price 955.989990, investment 4.856804 %, total balance 10259.985169,
# day 180: buy 1 unit at price 980.340027, total balance 9279.645142
# day 182: buy 1 unit at price 947.799988, total balance 8331.845154
# day 183, sell 1 unit at price 934.090027, investment -4.717751 %, total balance 9265.935181,
# day 184: buy 1 unit at price 941.530029, total balance 8324.405152
# day 185, sell 1 unit at price 930.500000, investment -1.825278 %, total balance 9254.905152,
# day 186, sell 1 unit at price 930.830017, investment -1.136449 %, total balance 10185.735169,
# day 189: buy 1 unit at price 927.960022, total balance 9257.775147
# day 190, sell 1 unit at price 929.359985, investment 0.150865 %, total balance 10187.135132,
# day 191: buy 1 unit at price 926.789978, total balance 9260.345154
# day 193: buy 1 unit at price 907.239990, total balance 8353.105164
# day 194, sell 1 unit at price 914.390015, investment -1.337947 %, total balance 9267.495179,
# day 195, sell 1 unit at price 922.669983, investment 1.700762 %, total balance 10190.165162,
# day 198: buy 1 unit at price 910.979980, total balance 9279.185182
# day 199: buy 1 unit at price 910.669983, total balance 8368.515199
# day 200: buy 1 unit at price 906.659973, total balance 7461.855226
# day 201: buy 1 unit at price 924.690002, total balance 6537.165224
# day 202, sell 1 unit at price 927.000000, investment 1.758548 %, total balance 7464.165224,
# day 205, sell 1 unit at price 913.809998, investment 0.344803 %, total balance 8377.975222,
# day 206: buy 1 unit at price 921.289978, total balance 7456.685244
# day 207, sell 1 unit at price 929.570007, investment 2.526861 %, total balance 8386.255251,
# day 209, sell 1 unit at price 937.340027, investment 1.368029 %, total balance 9323.595278,
# day 211, sell 1 unit at price 927.809998, investment 0.707706 %, total balance 10251.405276,
# day 225: buy 1 unit at price 924.859985, total balance 9326.545291
# day 227, sell 1 unit at price 949.500000, investment 2.664189 %, total balance 10276.045291,
# day 235: buy 1 unit at price 972.599976, total balance 9303.445315
# day 237, sell 1 unit at price 987.830017, investment 1.565910 %, total balance 10291.275332,

# %%
fig = plt.figure(figsize = (15,5))
plt.rcParams['axes.facecolor'] = 'dimgrey'

plt.plot(close, color='#EFEFEF', lw=2.)
plt.plot(close, '^', markersize=7, color='#ED6F2F', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=7, color='#8CC55D', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
